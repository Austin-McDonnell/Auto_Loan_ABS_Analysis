# %%
# %matplotlib inline
import os
os.chdir('U:\\GitHubClones\\SALTSeniorDesign')
import pandas as pd
import numpy as np
import Excel
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
import re
from datetime import datetime

# %%
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 1000)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
umRatePath = 'U:\\GitHubClones\\SALTSeniorDesign\\' + 'State_level_unemployment_rate.csv'
umrate = pd.read_csv(umRatePath, memory_map=True, low_memory=False)
umrate
# Out:
#         Date   AK   AL   AR   AZ   CA   CO   CT   DC   DE   FL   GA   HI   IA   ID   IL   IN   KS   KY   LA   MA   MD   ME   MI   MN   MO   MS   MT   NC   ND   NE   NH   NJ   NM   NV   NY   OH   OK   OR   PA   RI   SC   SD   TN   TX   UT   VA   VT   WA   WI   WV   WY
# 0   1/1/2017  6.5  6.4  3.8  5.0  5.2  2.9  4.5  5.7  4.4  5.0  5.5  2.8  3.4  3.6  5.7  4.0  4.1  5.0  5.9  3.2  4.2  3.5  5.2  4.0  4.2  5.5  3.9  5.3  3.0  3.3  2.7  4.6  6.7  5.0  4.6  5.0  4.7  4.3  5.2  4.8  4.4  2.9  5.4  4.8  3.1  4.0  3.1  5.1  3.9  5.6  4.8
# 1   2/1/2017  6.4  6.2  3.7  5.1  5.0  2.9  4.7  5.7  4.5  5.0  5.3  2.8  3.2  3.6  5.4  4.1  4.0  5.0  5.8  3.4  4.2  3.2  5.3  4.0  4.1  5.2  3.9  5.1  3.0  3.2  2.7  4.5  6.8  4.9  4.4  5.1  4.5  4.0  5.0  4.5  4.4  2.8  5.3  4.9  3.1  3.9  3.0  4.9  3.7  5.2  4.7
# ...

# %%
stateDict = umrate.to_dict(orient='index')
stateDict
# Out:
# {'1/1/2017': {'AK': 6.5,
#   'AL': 6.4000000000000004,
#   'AR': 3.7999999999999998,
#   'AZ': 5.0,
#   'CA': 5.2000000000000002,
#   'CO': 2.8999999999999999,
#   'CT': 4.5,
#   'DC': 5.7000000000000002,
#   'DE': 4.4000000000000004,
#   'FL': 5.0,
#   'GA': 5.5,
#   'HI': 2.7999999999999998,
#   'IA': 3.3999999999999999,
#   'ID': 3.6000000000000001,
#   'IL': 5.7000000000000002,
#   'IN': 4.0,
#   'KS': 4.0999999999999996,
#   'KY': 5.0,
#   'LA': 5.9000000000000004,
#   'MA': 3.2000000000000002,
#   'MD': 4.2000000000000002,
#   'ME': 3.5,
#   'MI': 5.2000000000000002,
#   'MN': 4.0,
#   'MO': 4.2000000000000002,
#   'MS': 5.5,
#   'MT': 3.8999999999999999,
#   'NC': 5.2999999999999998,
#   'ND': 3.0,
#   'NE': 3.2999999999999998,
#   'NH': 2.7000000000000002,
#   'NJ': 4.5999999999999996,
#   'NM': 6.7000000000000002,
#   'NV': 5.0,
#   'NY': 4.5999999999999996,
#   'OH': 5.0,
#   'OK': 4.7000000000000002,
#   'OR': 4.2999999999999998,
#   'PA': 5.2000000000000002,
# ...

# %%
stateDict['1/1/2017'].get('AK')
# Out:
# 6.5

# %%
states = ['AK', 'GA', 'DE', 'ID']
begReportPeriod = ['1/1/2017','1/1/2017',]
df = pd.DataFrame({'begReport':begReportPeriod})
uniqueList = df.begReport.unique()
print(uniqueList)
states
df
# Out:
# ['1/1/2017']
#   begReport
# 0  1/1/2017
# 1  1/1/2017

# %%
print(stateDict['1/1/2017'].get('AK'))
# Out:
# 6.5

# %%
umList = []
for i in range(0,len(uniqueList)):
    for j in range(0, len(states)):
        val = stateDict[uniqueList[i]].get(states[j])
        print(val)
        umList.append(val)
umList
# Out:
# 6.5
# 5.5
# 4.4
# 3.6
# [6.5, 5.5, 4.4000000000000004, 3.6000000000000001]

# %%
path = Excel.directory + "\\" + Excel.shelf + "\\" + Excel.deal + "\\" + Excel.dfTapes[Excel.deal][0]
print(path)
df = pd.read_csv(path, memory_map=True, low_memory=False)
# Out:
# U:\AutoLoanTapes\Santander Drive Auto Receivables Trust\SDART 2017-1\2017\01 January\2017.02.15_Santander Drive Auto Receivables Trust 2017-1 Data Tape.csv

# %%
umrate['Date'] = pd.to_datetime(umrate.Date)
umrate['Date'] = umrate['Date'].dt.strftime('%m/%d/%Y')

# %%
umrate = umrate.set_index('Date')
umrate.head()
# Out:
#              AK   AL   AR   AZ   CA   CO   CT   DC   DE   FL   GA   HI   IA   ID   IL   IN   KS   KY   LA   MA   MD   ME   MI   MN   MO   MS   MT   NC   ND   NE   NH   NJ   NM   NV   NY   OH   OK   OR   PA   RI   SC   SD   TN   TX   UT   VA   VT   WA   WI   WV   WY
# Date
# 01/01/2017  6.5  6.4  3.8  5.0  5.2  2.9  4.5  5.7  4.4  5.0  5.5  2.8  3.4  3.6  5.7  4.0  4.1  5.0  5.9  3.2  4.2  3.5  5.2  4.0  4.2  5.5  3.9  5.3  3.0  3.3  2.7  4.6  6.7  5.0  4.6  5.0  4.7  4.3  5.2  4.8  4.4  2.9  5.4  4.8  3.1  4.0  3.1  5.1  3.9  5.6  4.8
# 02/01/2017  6.4  6.2  3.7  5.1  5.0  2.9  4.7  5.7  4.5  5.0  5.3  2.8  3.2  3.6  5.4  4.1  4.0  5.0  5.8  3.4  4.2  3.2  5.3  4.0  4.1  5.2  3.9  5.1  3.0  3.2  2.7  4.5  6.8  4.9  4.4  5.1  4.5  4.0  5.0  4.5  4.4  2.8  5.3  4.9  3.1  3.9  3.0  4.9  3.7  5.2  4.7
# ...

# %%
stateDict = umrate.to_dict(orient='index')

# %%
df['reportingPeriodBeginningDate'] = pd.to_datetime(df['reportingPeriodBeginningDate']).dt.strftime('%m/%d/%Y')
df['reportingPeriodBeginningDate'].head()
# Out:
# 0    01/01/2017
# 1    01/01/2017
# 2    01/01/2017
# 3    01/01/2017
# 4    01/01/2017
# Name: reportingPeriodBeginningDate, dtype: object

# %%
states = list(df['obligorGeographicLocation'])
uniqueList = df.reportingPeriodBeginningDate.unique()
umList = []
#print(df.describe())
for i in range(0, len(states)):
    val = stateDict[uniqueList[0]].get(states[i])
    #print(val)
    umList.append(val)
#print(len(umList))
df['StateUnemployment'] = umList

# %%
df[['obligorGeographicLocation','StateUnemployment']]
# Out:
#       obligorGeographicLocation  StateUnemployment
# 0                            AZ                5.0
# 1                            TX                4.8
# 2                            WA                5.1
# 3                            FL                5.0
# 4                            IL                5.7
# 5                            VA                4.0
# 6                            CA                5.2
# 7                            NY                4.6
# 8                            TX                4.8
# 9                            TX                4.8
# 10                           FL                5.0
# 11                           NC                5.3
# 12                           UT                3.1
# 13                           OH                5.0
# 14                           NV                5.0
# 15                           FL                5.0
# 16                           DC                5.7
# ...
